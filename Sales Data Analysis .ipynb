# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\yug\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yug\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yug\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yug\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yug\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\yug\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_csv('sales_data.csv')
df
# Out:
#     Order_ID  Order_Date Region       City     Product     Category  Quantity  \
# 0       1001  2023-01-05  North      Delhi      Laptop  Electronics         2
# 1       1002  2023-01-07  South  Bangalore      Mobile  Electronics         3
# 2       1003  2023-01-10   East    Kolkata      Tablet  Electronics         1
# 3       1004  2023-01-15   West     Mumbai  Headphones  Accessories         5
# 4       1005  2023-02-01  North      Delhi      Laptop  Electronics         1
# 5       1006  2023-02-03  South  Bangalore    Keyboard  Accessories         4
# 6       1007  2023-02-10   East    Kolkata       Mouse  Accessories         6
# 7       1008  2023-02-14   West     Mumbai      Mobile  Electronics         2
# 8       1009  2023-03-02  North      Delhi      Tablet  Electronics         2
# 9       1010  2023-03-05  South  Bangalore      Laptop  Electronics         1
# 10      1011  2023-03-08   East    Kolkata  Headphones  Accessories         3
# 11      1012  2023-03-15   West     Mumbai       Mouse  Accessories         5
# 12      1013  2023-04-01  North      Delhi      Mobile  Electronics         2
# 13      1014  2023-04-03  South  Bangalore      Tablet  Electronics         1
# 14      1015  2023-04-07   East    Kolkata      Laptop  Electronics         1
# 15      1016  2023-04-10   West     Mumbai    Keyboard  Accessories         3
# 16      1017  2023-05-02  North      Delhi       Mouse  Accessories         4
# 17      1018  2023-05-05  South  Bangalore  Headphones  Accessories         2
# 18      1019  2023-05-10   East    Kolkata      Mobile  Electronics         3
# 19      1020  2023-05-15   West     Mumbai      Laptop  Electronics         2
#
#     Unit_Price   Sales   Profit Customer_Type
# 0        55000  110000  15000.0           New
# 1        20000   60000   8000.0     Returning
# 2        30000   30000   4000.0           New
# 3         2000   10000   2500.0     Returning
# 4        55000   55000      NaN           New
# 5         1500    6000   1200.0           New
# 6          800    4800    900.0     Returning
# 7        20000   40000   6000.0           New
# 8        30000   60000   7000.0     Returning
# 9        55000   55000   9000.0           New
# 10        2000    6000   1200.0           NaN
# 11         800    4000    700.0     Returning
# 12       20000   40000   5000.0           New
# 13       30000   30000   4500.0     Returning
# 14       55000   55000  10000.0           New
# 15        1500    4500    900.0           New
# 16         800    3200    600.0     Returning
# 17        2000    4000    700.0           New
# 18       20000   60000   9000.0     Returning
# 19       55000  110000  18000.0           New

# %%
df.head()
# Out:
#    Order_ID  Order_Date Region       City     Product     Category  Quantity  \
# 0      1001  2023-01-05  North      Delhi      Laptop  Electronics         2
# 1      1002  2023-01-07  South  Bangalore      Mobile  Electronics         3
# 2      1003  2023-01-10   East    Kolkata      Tablet  Electronics         1
# 3      1004  2023-01-15   West     Mumbai  Headphones  Accessories         5
# 4      1005  2023-02-01  North      Delhi      Laptop  Electronics         1
#
#    Unit_Price   Sales   Profit Customer_Type
# 0       55000  110000  15000.0           New
# 1       20000   60000   8000.0     Returning
# 2       30000   30000   4000.0           New
# 3        2000   10000   2500.0     Returning
# 4       55000   55000      NaN           New

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       20 non-null     int64
#  1   Order_Date     20 non-null     object
#  2   Region         20 non-null     object
#  3   City           20 non-null     object
#  4   Product        20 non-null     object
#  5   Category       20 non-null     object
#  6   Quantity       20 non-null     int64
#  7   Unit_Price     20 non-null     int64
#  8   Sales          20 non-null     int64
#  9   Profit         19 non-null     float64
#  10  Customer_Type  19 non-null     object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.8+ KB

# %%
df.describe()
# Out:
#          Order_ID   Quantity    Unit_Price          Sales        Profit
# count    20.00000  20.000000     20.000000      20.000000     19.000000
# mean   1010.50000   2.650000  22820.000000   37375.000000   5484.210526
# std       5.91608   1.496487  21798.565863   33556.486156   5065.598918
# min    1001.00000   1.000000    800.000000    3200.000000    600.000000
# 25%    1005.75000   1.750000   1875.000000    5700.000000   1050.000000
# 50%    1010.50000   2.000000  20000.000000   35000.000000   4500.000000
# 75%    1015.25000   3.250000  36250.000000   56250.000000   8500.000000
# max    1020.00000   6.000000  55000.000000  110000.000000  18000.000000

# %%
df
# Out:
#     Order_ID  Order_Date Region       City     Product     Category  Quantity  \
# 0       1001  2023-01-05  North      Delhi      Laptop  Electronics         2
# 1       1002  2023-01-07  South  Bangalore      Mobile  Electronics         3
# 2       1003  2023-01-10   East    Kolkata      Tablet  Electronics         1
# 3       1004  2023-01-15   West     Mumbai  Headphones  Accessories         5
# 4       1005  2023-02-01  North      Delhi      Laptop  Electronics         1
# 5       1006  2023-02-03  South  Bangalore    Keyboard  Accessories         4
# 6       1007  2023-02-10   East    Kolkata       Mouse  Accessories         6
# 7       1008  2023-02-14   West     Mumbai      Mobile  Electronics         2
# 8       1009  2023-03-02  North      Delhi      Tablet  Electronics         2
# 9       1010  2023-03-05  South  Bangalore      Laptop  Electronics         1
# 10      1011  2023-03-08   East    Kolkata  Headphones  Accessories         3
# 11      1012  2023-03-15   West     Mumbai       Mouse  Accessories         5
# 12      1013  2023-04-01  North      Delhi      Mobile  Electronics         2
# 13      1014  2023-04-03  South  Bangalore      Tablet  Electronics         1
# 14      1015  2023-04-07   East    Kolkata      Laptop  Electronics         1
# 15      1016  2023-04-10   West     Mumbai    Keyboard  Accessories         3
# 16      1017  2023-05-02  North      Delhi       Mouse  Accessories         4
# 17      1018  2023-05-05  South  Bangalore  Headphones  Accessories         2
# 18      1019  2023-05-10   East    Kolkata      Mobile  Electronics         3
# 19      1020  2023-05-15   West     Mumbai      Laptop  Electronics         2
#
#     Unit_Price   Sales   Profit Customer_Type
# 0        55000  110000  15000.0           New
# 1        20000   60000   8000.0     Returning
# 2        30000   30000   4000.0           New
# 3         2000   10000   2500.0     Returning
# 4        55000   55000      NaN           New
# 5         1500    6000   1200.0           New
# 6          800    4800    900.0     Returning
# 7        20000   40000   6000.0           New
# 8        30000   60000   7000.0     Returning
# 9        55000   55000   9000.0           New
# 10        2000    6000   1200.0           NaN
# 11         800    4000    700.0     Returning
# 12       20000   40000   5000.0           New
# 13       30000   30000   4500.0     Returning
# 14       55000   55000  10000.0           New
# 15        1500    4500    900.0           New
# 16         800    3200    600.0     Returning
# 17        2000    4000    700.0           New
# 18       20000   60000   9000.0     Returning
# 19       55000  110000  18000.0           New

# %%
total_sales = df['Sales'].sum()
print(total_sales)
# Out:
# 747500

# %%
total_profit = df['Profit'].sum()
print(total_profit)
# Out:
# 104200.0

# %%
max_sales = df.nlargest(5,'Sales')
max_sales
# Out:
#     Order_ID  Order_Date Region       City Product     Category  Quantity  \
# 0       1001  2023-01-05  North      Delhi  Laptop  Electronics         2
# 19      1020  2023-05-15   West     Mumbai  Laptop  Electronics         2
# 1       1002  2023-01-07  South  Bangalore  Mobile  Electronics         3
# 8       1009  2023-03-02  North      Delhi  Tablet  Electronics         2
# 18      1019  2023-05-10   East    Kolkata  Mobile  Electronics         3
#
#     Unit_Price   Sales   Profit Customer_Type
# 0        55000  110000  15000.0           New
# 19       55000  110000  18000.0           New
# 1        20000   60000   8000.0     Returning
# 8        30000   60000   7000.0     Returning
# 18       20000   60000   9000.0     Returning

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Sales'])

# %%
result = df.groupby('Region')['Sales'].sum()
print(result)
# Out:
# Region
# East     155800
# North    268200
# South    155000
# West     168500
# Name: Sales, dtype: int64
